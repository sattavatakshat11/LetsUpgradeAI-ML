# %%
# Hypothesis Testing for the mean!

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 
from scipy.stats import pearsonr

# %%
df = pd.read_csv("final.csv",index_col = None)

# %%
df.head(3)
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  Gender  JobLevel                    JobRole  ...  \
# 0          2  Life Sciences  Female         1  Healthcare Representative  ...
# 1          1  Life Sciences  Female         1         Research Scientist  ...
# 2          1        Medical    Male         1            Sales Executive  ...
#
#   NumCompaniesWorked  Over18  PercentSalaryHike StandardHours  \
# 0                1.0       Y                 11             8
# 1                0.0       Y                 23             8
# 2                4.0       Y                 12             8
#
#    StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  YearsAtCompany  \
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'Gender', 'JobLevel', 'JobRole',
#        'MaritalStatus', 'MonthlyIncome', 'NumCompaniesWorked', 'Over18',
#        'PercentSalaryHike', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
df.drop('Unnamed: 0',inplace=True,axis = 1)

# %%
# Now dataset is imported final wala dataset hai jisme mein se we tried to remove all the outliers!

# %%
# Converting dataset into two parts attrition data and non attrition data

# %%
attrition = df[df["Attrition"] == "Yes"]

# %%
non =df[df["Attrition"] == "No"]

# %%
asamp = df.sample(n=20)

# %%
asamp.describe()
# Out:
#              Age  DistanceFromHome  Education   JobLevel  MonthlyIncome  \
# count  20.000000         20.000000  20.000000  20.000000      20.000000
# mean   34.400000          8.450000   2.850000   2.300000   53026.000000
# std     8.512529          6.533114   1.089423   1.341641   30155.585046
# min    18.000000          2.000000   1.000000   1.000000   12610.000000
# 25%    28.000000          5.000000   2.000000   1.000000   30622.500000
# 50%    33.500000          6.500000   3.000000   2.000000   45095.000000
# 75%    39.000000          8.500000   4.000000   3.000000   77965.000000
# max    51.000000         29.000000   4.000000   5.000000  116310.000000
#
#        NumCompaniesWorked  PercentSalaryHike  StandardHours  StockOptionLevel  \
# count           20.000000          20.000000           20.0         20.000000
# mean             1.650000          15.900000            8.0          0.650000
# std              1.089423           3.596782            0.0          0.812728
# ...

# %%
df.describe()
# Out:
#                Age  DistanceFromHome    Education     JobLevel  MonthlyIncome  \
# count  2870.000000       2870.000000  2870.000000  2870.000000    2870.000000
# mean     34.355749          9.040767     2.918467     2.095470   58113.243902
# std       8.061021          8.014152     1.003813     1.119217   36831.757477
# min      18.000000          1.000000     1.000000     1.000000   10510.000000
# 25%      29.000000          2.000000     2.000000     1.000000   28620.000000
# 50%      34.000000          7.000000     3.000000     2.000000   47730.000000
# 75%      38.000000         13.000000     4.000000     3.000000   74375.000000
# max      60.000000         29.000000     5.000000     5.000000  173990.000000
#
#        NumCompaniesWorked  PercentSalaryHike  StandardHours  StockOptionLevel  \
# count         2870.000000        2870.000000         2870.0       2870.000000
# mean             2.161324          15.178049            8.0          0.810105
# ...

# %%
# Null Hyptohesis : the mean distance from the home is 8.900
# Alternative hypothesis  : the mean distance from home is not 8.900

# 2 - Statistical Test:
#     z test :
#         Calculated value  = 0.07
#         table value is 2.086
#         so confidence interval is -2.086 - +2.086
#         calculated value falls within the given interval so null hypothesis is accepted!

# %%
nd = ['Age', 'DistanceFromHome', 'MonthlyIncome',
       'NumCompaniesWorked',  'PercentSalaryHike', 'StandardHours',
        'TotalWorkingYears', 'TrainingTimesLastYear',
       'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager']

# %%
def hypo(a):
    table_value_positive = 2.086
    table_value_negative = -2.086
    for i in a:
        
        print("Null Hypothesis: The average mean of the poulation parameter" , i ,"=",asamp[i].mean(),"\n")
        print("Alternative Hypothesis: The average mean of the poulation parameter" , i ,"is not equal to",asamp[i].mean(),"\n")
        
        print("The average value of dataset is",df[i].mean(),"\n")
        print("The average value of the sample is " , asamp[i].mean(),"\n")
        
        calculated_value = (int(asamp[i].mean()) - int(df[i].mean())) / (df[i].std() / np.sqrt(20))
        print("calculated value :" , calculated_value)
        print("Table Value :",table_value_negative , table_value_positive)
        
        if (calculated_value < table_value_positive) | (calculated_value > table_value_negative):
            print("###################################################")
            print("Null hypothesis of " , i, "is accepted", " \n")
            print("###################################################")
            print("\n")
        else:
            print("Alternative hypothesis of", i , "is accepted")
            print("\n")

# %%
hypo(nd)
# Out:
# Null Hypothesis: The average mean of the poulation parameter Age = 34.4
#
# Alternative Hypothesis: The average mean of the poulation parameter Age is not equal to 34.4
#
# The average value of dataset is 34.35574912891986
#
# The average value of the sample is  34.4
#
# calculated value : 0.0
# Table Value : -2.086 2.086
# ###################################################
# Null hypothesis of  Age is accepted
#
# ###################################################
#
#
# Null Hypothesis: The average mean of the poulation parameter DistanceFromHome = 8.45
#
# Alternative Hypothesis: The average mean of the poulation parameter DistanceFromHome is not equal to 8.45
#
# The average value of dataset is 9.040766550522648
#
# The average value of the sample is  8.45
#
# calculated value : -0.5580298058148522
# Table Value : -2.086 2.086
# ###################################################
# Null hypothesis of  DistanceFromHome is accepted
#
# ...

# %%
# The above analysis gives the assurance to us that the take sample is perfect
